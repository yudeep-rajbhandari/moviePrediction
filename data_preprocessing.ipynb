# %%
import pandas as pd
import os
import neo4j

def date_compare(date1,date2):
    if(date1.split('/',1)):
        date_A,date_B=date1.split('/',1)
    else:
        date_A=date1
        
    date2,date3=date2.split('-',1)
    
    if ((-2<=int(date_A)-int(date2)<=2) or (-2<=int(date_B)-int(date2)<=2)):
        return True
    else:
        return False

# %%
df1=pd.read_csv("resources/database.csv",encoding = "ISO-8859-1")
df1=df1.dropna(subset=['Film'])
df1['Film']=df1['Film'].str.strip()
df1 = df1.loc[:, ~df1.columns.str.contains('^Unnamed')]
df2=pd.read_csv("resources/movies_metadata.csv",converters={'title': str.strip})

df3=df1.merge(df2, left_on = 'Film', right_on = 'title')
date_compare('1927/1928','1925-09-08')
df3
# Out:
#            Year  Ceremony                                 Award  Winner  \
# 0     1927/1928         1                                 Actor     NaN
# 1     1927/1928         1                                 Actor     1.0
# 2     1927/1928         1              Writing (Original Story)     NaN
# 3     1927/1928         1                               Actress     1.0
# 4     1927/1928         1                         Art Direction     NaN
# 5     1927/1928         1          Directing (Dramatic Picture)     1.0
# 6     1927/1928         1                   Outstanding Picture     NaN
# 7     1927/1928         1                  Writing (Adaptation)     1.0
# 8     1927/1928         1                               Actress     NaN
# 9     1927/1928         1                         Art Direction     NaN
# 10    1927/1928         1                        Cinematography     1.0
# 11    1927/1928         1                        Cinematography     1.0
# ...

# %%
# Out:
#   File "<ipython-input-14-46c706c715bd>", line 1
#     LOAD CSV WITH HEADERS FROM 'file://C:\Users\Diana\Documents\Nattosphere\Natto_Sample.csv'
#            ^
# SyntaxError: invalid syntax
